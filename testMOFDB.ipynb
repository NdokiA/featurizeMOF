# %%
# !pip install requirements.txt

# %%
from workFunc.extractMOFDB import MOFDatasetBuilder

# %%
mofDB = MOFDatasetBuilder()
mofDB.build_dataset(gas="methane",limit=5)
# Out:
# Processing MOFs: 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:04<00:00,  1.14it/s]
# Saved 30 records to Dataset/mofs_data.json
